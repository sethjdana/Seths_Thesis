# %%
'''

#Enable GPU for this Exercise.

'''
# Out:
# '\n\n#Enable GPU for this Exercise.\n\n'

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
from torchvision import datasets, transforms
import numpy as np
from torch.utils.data import Dataset, random_split
from torch.utils.data import DataLoader


# This package is helpful to apply noise to our images
import skimage

#If CUDA is available, use CUDA or else default to CPU.
device = 'cuda' if torch.cuda.is_available() else 'cpu'


'''
Import Mnist
'''

batch_size = 64

transform = transforms.Compose([transforms.ToTensor()])

mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)

mnist_testset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)

len(mnist_trainset)
len(mnist_testset)




'''
Normalize each input from [0.0,1.0] range
'''
#transforming with ToTensor() will normalize the data for me


'''
Reshape X to have 4 dimension that is batch_size, channels, Height, Width
'''
X_train = mnist_trainset.data
y_train = mnist_trainset.targets

X_test = mnist_testset.data
y_test = mnist_testset.targets

val_size = 5000
test_size = 5000

# valset, testset = random_split(X_test, [val_size, test_size])

#add dimention in the 1 spot for batch size
# X_train = X_train.unsqueeze(1)
# X_test = X_test.unsqueeze(1)



print(X_train.shape)
print(X_test.shape)
# Out:
# torch.Size([60000, 28, 28])
# torch.Size([10000, 28, 28])

# %%
#before
plt.figure(figsize=(13,8))

num_examples = 5

for i in range(num_examples):
    plt.subplot(3, num_examples, i+1)
    plt.imshow(X_train[i], cmap='gray')
    plt.xticks([])
    plt.yticks([])
    plt.title('Original')

# create your training sets (X_train_GN) and (X_train_SP)


#Salt and pepper



X_train_SP = skimage.util.random_noise(X_train, mode='s&p', amount=0.05)
X_test_SP = skimage.util.random_noise(X_test, mode='s&p', amount=0.05)

for i in range(num_examples):
    plt.subplot(3, num_examples, i+6)
    plt.imshow(X_train_SP[i], cmap='gray')
    plt.xticks([])
    plt.yticks([])
    plt.title('Salt & Pepper')

#Gaussian Noise

X_train_GN = skimage.util.random_noise(X_train, mode='gaussian')

for i in range(num_examples):
    plt.subplot(3, num_examples, i+11)
    plt.imshow(X_train_GN[i], cmap='gray')
    plt.xticks([])
    plt.yticks([])
    plt.title('Gaussian Noise')

# %%
'''
Create the arquitecture 

'''

class Autoencoder(nn.Module):
    def __init__(self, encoded_space_dim):
        super(Autoencoder, self).__init__()
        # you can use sequential of not 

        self.encoder = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, stride=2, padding=1),
            nn.ReLU(),
            nn.Conv2d(16, 8, kernel_size=3, stride=2, padding=1),
            nn.ReLU()
        )

        self.middle = nn.Sequential(
            nn.Linear(49, 50),
            nn.ReLU(),
            nn.Linear(50, encoded_space_dim),
            nn.ReLU(),
            nn.Linear(encoded_space_dim, 50),
            nn.ReLU(),
            nn.Linear(50, 49),
            nn.ReLU()
        )

        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(8, 16, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(16, 1, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.Sigmoid()
        )

    def forward(self, x):
        # print(x.shape)
        x = self.encoder(x)
        x = x.view(x.size(0), -1) #flatten the shape for fc layers
        # print(x.size())
        x = self.middle(x)
        x = x.view(x.size(0), 7, 7) #reshape before passing through decoder
        x = self.decoder(x)
        # print(x.shape)
        return x

def add_noise(images, noise_factor = 0.5):
    noisy_images = images + noise_factor * torch.randn_like(images)
    return torch.clamp(noisy_images, 0.0, 1.0)

def train_autoencoder(model, train_data, num_epochs, lr):
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)

    for epoch in range(num_epochs):
        for data in train_data:
            images, _ = data
            # inputs = inputs.squeeze(1).to(device)
            noisy_im = add_noise(images)
            optimizer.zero_grad()
            # print(labels)
            outputs = model.forward(noisy_im)

            loss = criterion(outputs, images)
            # print(loss)
            loss.backward()
            optimizer.step()
            

        
        # test_loss = 0.0
        # with torch.no_grad():
        #     for X_in, y in test_loader:
        #         test_inputs, test_images = X_in.to(device).float(), y.to(device).float()
        #         test_outputs = model.forward(test_inputs)
        #         test_loss += criterion(test_outputs, test_images).item()

        
    model.eval()
    with torch.no_grad():
        for data in train_data:
            images, _ = data
            noisy_images = add_noise(images)

            outputs = model(noisy_images)

            plt.figure(figsize=(15, 5))
            for i in range(5):
                plt.subplot(2, 5, i + 1)
                plt.imshow(np.squeeze(noisy_images[i]), cmap='gray')
                plt.title('Noisy Image')
                plt.subplot(2, 5, i + 6)
                plt.imshow(np.squeeze(outputs[i]), cmap='gray')
                plt.title('Denoised Image')
            plt.show()
            break  # Display only the first batch
            # Plot the progress
        # with torch.no_grad():
        #     if (epoch+1)%1 == 0:
        #         print(f"TRAIN Epoch [{epoch + 1}/{num_epochs}] Loss: {loss.item():.3f}")
        #         print(f"TEST Epoch [{epoch + 1}/{num_epochs}] Loss: {loss.item():.3f}")
        #         plt.figure(figsize=(10, 4))
        #         for i in range(5):
        #             plt.subplot(2, 5, i + 1)
        #             plt.imshow(test_inputs[i].cpu().numpy(), cmap='gray')
        #             plt.title(f'Original {i + 1}')
        #             plt.axis('off')

        #             plt.subplot(2, 5, i + 6)
        #             plt.imshow(test_outputs[i].cpu().detach().numpy(), cmap='gray')
        #             plt.title(f'Output {i + 1}')
        #             plt.axis('off')

        #     plt.show()

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
'''
Define your training routine,
your optimizer, your loss function.
Everything you need to train the model
'''
encoded_space_dim = 32
batch_size = 1
lr = 0.001
num_epochs = 10

# train_loader_SP = torch.utils.data.DataLoader(X_train_SP.astype(np.float32), batch_size=batch_size)
# y_label_loader = torch.utils.data.DataLoader(y_train, batch_size=batch_size)

trainset_SP = CustomDataset(torch.tensor(X_train_SP.astype(np.float32)), X_train)
testset_SP = CustomDataset(torch.tensor(X_test_SP.astype(np.float32)), X_test)

train_loader_SP = torch.utils.data.DataLoader(trainset_SP, batch_size=batch_size)
test_loader_SP = torch.utils.data.DataLoader(testset_SP, batch_size=batch_size)
# look = trainset_SP.__getitem__(82)

# print(look[1])

# %%
import torchvision

# define the netowrk to be train with the salt and peper corrupted images
# train the network
transform = transforms.Compose([transforms.ToTensor()])
train_dataset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)


AutoNN_SP = Autoencoder(encoded_space_dim = encoded_space_dim).to(device)

train_autoencoder(AutoNN_SP ,train_dataloader, num_epochs=num_epochs, lr=lr)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# c:\Users\a02185015\Seths_Thesis\HW5_STAT6685\Autoencoder copy.ipynb Cell 7 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/a02185015/Seths_Thesis/HW5_STAT6685/Autoencoder%20copy.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a> train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)
#      <a href='vscode-notebook-cell:/c%3A/Users/a02185015/Seths_Thesis/HW5_STAT6685/Autoencoder%20copy.ipynb#W6sZmlsZQ%3D%3D?line=9'>10</a> AutoNN_SP = Autoencoder(encoded_space_dim = encoded_space_dim).to(device)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/a02185015/Seths_Thesis/HW5_STAT6685/Autoencoder%20copy.ipynb#W6sZmlsZQ%3D%3D?line=11'>12</a> train_autoencoder(AutoNN_SP ,train_dataloader, num_epochs=num_epochs, lr=lr)
#
# c:\Users\a02185015\Seths_Thesis\HW5_STAT6685\Autoencoder copy.ipynb Cell 7 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/a02185015/Seths_Thesis/HW5_STAT6685/Autoencoder%20copy.ipynb#W6sZmlsZQ%3D%3D?line=59'>60</a> optimizer.zero_grad()
#      <a href='vscode-notebook-cell:/c%3A/Users/a02185015/Seths_Thesis/HW5_STAT6685/Autoencoder%20copy.ipynb#W6sZmlsZQ%3D%3D?line=60'>61</a> # print(labels)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/a02185015/Seths_Thesis/HW5_STAT6685/Autoencoder%20copy.ipynb#W6sZmlsZQ%3D%3D?line=61'>62</a> outputs = model.forward(noisy_im)
#      <a href='vscode-notebook-cell:/c%3A/Users/a02185015/Seths_Thesis/HW5_STAT6685/Autoencoder%20copy.ipynb#W6sZmlsZQ%3D%3D?line=63'>64</a> loss = criterion(outputs, images)
#      <a href='vscode-notebook-cell:/c%3A/Users/a02185015/Seths_Thesis/HW5_STAT6685/Autoencoder%20copy.ipynb#W6sZmlsZQ%3D%3D?line=64'>65</a> # print(loss)
#
# c:\Users\a02185015\Seths_Thesis\HW5_STAT6685\Autoencoder copy.ipynb Cell 7 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/a02185015/Seths_Thesis/HW5_STAT6685/Autoencoder%20copy.ipynb#W6sZmlsZQ%3D%3D?line=35'>36</a> def forward(self, x):
#      <a href='vscode-notebook-cell:/c%3A/Users/a02185015/Seths_Thesis/HW5_STAT6685/Autoencoder%20copy.ipynb#W6sZmlsZQ%3D%3D?line=36'>37</a>     # print(x.shape)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/a02185015/Seths_Thesis/HW5_STAT6685/Autoencoder%20copy.ipynb#W6sZmlsZQ%3D%3D?line=37'>38</a>     x = self.encoder(x)
#      <a href='vscode-notebook-cell:/c%3A/Users/a02185015/Seths_Thesis/HW5_STAT6685/Autoencoder%20copy.ipynb#W6sZmlsZQ%3D%3D?line=38'>39</a>     x = x.view(x.size(0), -1) #flatten the shape for fc layers
#      <a href='vscode-notebook-cell:/c%3A/Users/a02185015/Seths_Thesis/HW5_STAT6685/Autoencoder%20copy.ipynb#W6sZmlsZQ%3D%3D?line=39'>40</a>     # print(x.size())
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\conv.py:463, in Conv2d.forward(self, input)
#     462 def forward(self, input: Tensor) -> Tensor:
# --> 463     return self._conv_forward(input, self.weight, self.bias)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\conv.py:459, in Conv2d._conv_forward(self, input, weight, bias)
#     455 if self.padding_mode != 'zeros':
#     456     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                     weight, bias, self.stride,
#     458                     _pair(0), self.dilation, self.groups)
# --> 459 return F.conv2d(input, weight, bias, self.stride,
#     460                 self.padding, self.dilation, self.groups)
#
# RuntimeError: Input type (torch.FloatTensor) and weight type (torch.cuda.FloatTensor) should be the same or input should be a MKLDNN tensor and weight is a dense tensor

# %%
# define the netowrk to be train with the gaussian corrupted images
# train the network 
AutoNN_GN = Autoencoder().to(device)

# %%
# corrupt test images with Salt and peper, pass them through AutoNN_SP 
# plot the results

# %%
# corrupt test images with Gaussian noise, pass them through AutoNN_GN
# plot the results
